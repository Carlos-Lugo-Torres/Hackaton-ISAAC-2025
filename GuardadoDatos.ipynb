# %% [markdown]
# # Extracción de Datos
#
# ## Importación de Bibliotecas

# %%
from statsbombpy import sb
import pandas as pd
from pathlib import Path

#Crecenciales de StatsBomb
creds = {"user": "itam_hackathon@hudl.com", "passwd": "pGwIprel"}

# %% [markdown]
# ## Competencias

# %%
competencias = sb.competitions(creds=creds)
competencias.to_parquet("Datos/Competencias/competencias.parquet")
competencias
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              73        317       Mexico          Liga MX               male
# 1              73        281       Mexico          Liga MX               male
# 2              73        235       Mexico          Liga MX               male
# 3              73        108       Mexico          Liga MX               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2024/2025
# 1              False                      False   2023/2024
# 2              False                      False   2022/2023
# 3              False                      False   2021/2022
#
#                 match_updated           match_updated_360  \
# 0  2025-08-30T16:14:20.970616  2025-08-30T16:14:20.970616
# 1  2024-12-20T23:40:31.103974  2024-12-20T23:40:31.103974
# 2  2024-09-28T11:05:11.667984  2024-09-28T11:05:11.667984
# 3  2024-12-10T08:59:57.612449  2024-12-10T08:59:57.612449
#
#           match_available_360             match_available
# 0  2025-08-30T16:14:20.970616  2025-08-30T16:14:20.970616
# 1  2024-12-20T23:40:31.103974  2024-12-20T23:40:31.103974
# 2  2024-09-28T11:05:11.667984  2024-09-28T11:05:11.667984
# 3  2024-12-10T08:59:57.612449  2024-12-10T08:59:57.612449

# %%
idsCompetencias = competencias[['competition_id', 'season_id']]
idsCompetencias
# Out:
#    competition_id  season_id
# 0              73        317
# 1              73        281
# 2              73        235
# 3              73        108

# %% [markdown]
# ## Partidos

# %%
def ensure_season_folder(base_dir: Path, season_id) -> Path:
    folder = base_dir / f"season_{season_id}"
    folder.mkdir(parents=True, exist_ok=True)
    return folder

# %%
# --- loop principal ---
partidos_list = []

BASE_DIR = Path("Datos") / "Partidos"  # raíz: Hackaton/Datos/Partidos

for competition_id, season_id in idsCompetencias.values:
    # 1) obtiene los partidos
    partidos = sb.matches(competition_id=competition_id, season_id=season_id, creds=creds)
    partidos["competition_id"] = competition_id
    partidos["season_id"] = season_id

    # 2) carpeta: Datos/Eventos/competition_<id>/season_<id>
    #output_folder = ensure_season_folder(BASE_DIR / f"competition_{competition_id}", season_id)

    # 3) guarda DENTRO de esa carpeta
    file_path = BASE_DIR / f"matches_competition_{competition_id}_season_{season_id}.parquet"
    partidos.to_parquet(file_path, index=False)

    print("Saved", str(file_path))  # p.ej. Datos\Eventos\competition_73\season_108\matches_competition_73_season_108.parquet

    # (opcional) lista de (season, competition, match)
    for match_id in partidos["match_id"].tolist():
        partidos_list.append((season_id, competition_id, match_id))
# Out:
# Saved Datos\Partidos\matches_competition_73_season_317.parquet
# Saved Datos\Partidos\matches_competition_73_season_281.parquet
# Saved Datos\Partidos\matches_competition_73_season_235.parquet
# Saved Datos\Partidos\matches_competition_73_season_108.parquet

# %% [markdown]
# ## Eventos

# %%
import pandas as pd

def limpiar_eventos(ev: pd.DataFrame) -> pd.DataFrame:
    columnas = [
        "player_id",
        "season_id",
        "competition_id",
        "player_name",
        "team_name",
        "match_id",
        "timestamp",
        "minute",
        "second",
        "type",
        "type_name",
        "under_pressure",
        "counterpress",
        "shot_end_location",
        "pass_end_location",
        "carry_end_location",
        "goalkeeper_end_location",
        "pass_height_name",
        "pass_body_part_name",
        "location",
        "location_x",
        "location_y",
        "shot_technique_name",
        "shot_body_part_name",
        "shot_first_time",
        "dribble_outcome_name",
        "possession_team"
    ]

    # Solo conserva las columnas que existan
    cols_presentes = [c for c in columnas if c in ev.columns]
    return ev[cols_presentes]

# %%
from pathlib import Path
from tqdm import tqdm
import pandas as pd
# import statsbombpy as sb  # asumiendo que ya lo tienes importado
# creds = {...}             # tus credenciales si aplican

BASE_EVENTS = Path("Datos") / "Eventos"

# partidos_list con tu estructura: (season_id, competition_id, match_id)
# Si no la tienes, puedes construirla a partir de tus DFs de matches.
# partidos_list = [(season_id, competition_id, match_id), ...]

def guardar_eventos_por_temporada(partidos_list, skip_existing=True):
    for season_id, competition_id, match_id in tqdm(partidos_list, desc="Descargando eventos"):
        out_dir = ensure_season_folder(BASE_EVENTS, season_id)  # Datos/Eventos/season_<id>
        out_path = out_dir / f"events_{match_id}.parquet"

        if skip_existing and out_path.exists():
            continue

        ev = sb.events(match_id=match_id, creds=creds)  # <- dataframe de eventos
        # añade metadatos útiles
        ev["season_id"] = season_id
        ev["competition_id"] = competition_id
        ev["match_id"] = match_id

        ev = limpiar_eventos(ev)

        ev.to_parquet(out_path, index=False)
        # print(f"Saved {out_path}")  # opcional

# %%
guardar_eventos_por_temporada(partidos_list)
# Out:
# Descargando eventos:   0%|          | 0/1364 [00:00<?, ?it/s]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   1%|          | 7/1364 [00:03<12:14,  1.85it/s]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 8/1364 [00:08<28:21,  1.25s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   1%|          | 9/1364 [00:13<44:33,  1.97s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   1%|          | 10/1364 [00:16<51:49,  2.30s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 11/1364 [00:20<58:09,  2.58s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 12/1364 [00:24<1:06:09,  2.94s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 13/1364 [00:28<1:11:23,  3.17s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   1%|          | 14/1364 [00:32<1:18:25,  3.49s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 15/1364 [00:36<1:22:39,  3.68s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 16/1364 [00:40<1:24:30,  3.76s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|          | 17/1364 [00:44<1:24:33,  3.77s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|▏         | 18/1364 [00:48<1:26:10,  3.84s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|▏         | 19/1364 [00:52<1:29:01,  3.97s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   1%|▏         | 20/1364 [00:56<1:27:08,  3.89s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 21/1364 [01:00<1:28:43,  3.96s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 22/1364 [01:05<1:31:36,  4.10s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 23/1364 [01:08<1:29:57,  4.02s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 24/1364 [01:12<1:30:20,  4.05s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 25/1364 [01:16<1:27:41,  3.93s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 26/1364 [01:20<1:27:29,  3.92s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 27/1364 [01:24<1:26:32,  3.88s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 28/1364 [01:28<1:29:06,  4.00s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 29/1364 [01:32<1:26:18,  3.88s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 30/1364 [01:36<1:28:30,  3.98s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 31/1364 [01:40<1:28:58,  4.01s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 32/1364 [01:44<1:28:31,  3.99s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 33/1364 [01:48<1:28:02,  3.97s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   2%|▏         | 34/1364 [01:53<1:33:32,  4.22s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   3%|▎         | 35/1364 [01:58<1:39:34,  4.50s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:   3%|▎         | 36/1364 [02:03<1:46:49,  4.83s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 37/1364 [02:09<1:49:20,  4.94s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 38/1364 [02:14<1:50:14,  4.99s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 39/1364 [02:19<1:49:27,  4.96s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 40/1364 [02:24<1:50:52,  5.02s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 41/1364 [02:28<1:46:02,  4.81s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 42/1364 [02:33<1:48:26,  4.92s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 43/1364 [02:38<1:48:58,  4.95s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 44/1364 [02:42<1:43:03,  4.68s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 45/1364 [02:47<1:43:53,  4.73s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 46/1364 [02:55<2:01:21,  5.52s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   3%|▎         | 47/1364 [03:00<1:58:20,  5.39s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:   4%|▎         | 48/1364 [03:05<1:55:20,  5.26s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# ...
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1349/1364 [1:35:52<01:08,  4.59s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:  99%|█████████▉| 1350/1364 [1:35:57<01:05,  4.67s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1351/1364 [1:36:02<00:59,  4.56s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1352/1364 [1:36:06<00:54,  4.55s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1353/1364 [1:36:10<00:47,  4.32s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1354/1364 [1:36:15<00:44,  4.44s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1355/1364 [1:36:19<00:39,  4.37s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos:  99%|█████████▉| 1356/1364 [1:36:23<00:35,  4.47s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos:  99%|█████████▉| 1357/1364 [1:36:28<00:31,  4.51s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos: 100%|█████████▉| 1358/1364 [1:36:32<00:26,  4.47s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos: 100%|█████████▉| 1359/1364 [1:36:37<00:22,  4.47s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos: 100%|█████████▉| 1360/1364 [1:36:42<00:18,  4.52s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos: 100%|█████████▉| 1361/1364 [1:36:46<00:13,  4.43s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos: 100%|█████████▉| 1362/1364 [1:36:50<00:08,  4.45s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# Descargando eventos: 100%|█████████▉| 1363/1364 [1:36:54<00:04,  4.31s/it]c:\venvs\py313\Lib\site-packages\statsbombpy\sb.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   events = pd.concat([*events.values()], axis=0, ignore_index=True, sort=True)
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["season_id"] = season_id
# C:\Users\clugo\AppData\Local\Temp\ipykernel_15600\1512482047.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ev["competition_id"] = competition_id
# Descargando eventos: 100%|██████████| 1364/1364 [1:36:58<00:00,  4.27s/it]

# %% [markdown]
# ## Player Season Stats

# %%
help (sb.player_season_stats)
# Out:
# Help on function player_season_stats in module statsbombpy.sb:
#
# player_season_stats(
#     competition_id: int,
#     season_id: int,
#     fmt='dataframe',
#     creds: dict = {'user': None, 'passwd': None}
# ) -> Union[pandas.core.frame.DataFrame, dict]

# %%
for competition_id, season_id in idsCompetencias.values:
    stats = sb.player_season_stats(competition_id=competition_id, season_id=season_id, creds=creds)

    stats['competition_id'] = competition_id
    stats['season_id'] = season_id

# %%
from pathlib import Path

BASE = Path("Datos/Player_Season_Stats")
BASE.mkdir(parents=True, exist_ok=True)

for competition_id, season_id in idsCompetencias.values:
    stats = sb.player_season_stats(
        competition_id=competition_id,
        season_id=season_id,
        creds=creds
    )

    stats["competition_id"] = competition_id
    stats["season_id"] = season_id

    out_path = BASE / f"player_season_stats_{season_id}.parquet"
    stats.to_parquet(out_path, index=False)   # requiere pyarrow o fastparquet
    print(f"✅ Guardado: {out_path}")
# Out:
# ✅ Guardado: Datos\Player_Season_Stats\player_season_stats_317.parquet
# ✅ Guardado: Datos\Player_Season_Stats\player_season_stats_281.parquet
# ✅ Guardado: Datos\Player_Season_Stats\player_season_stats_235.parquet
# ✅ Guardado: Datos\Player_Season_Stats\player_season_stats_108.parquet
